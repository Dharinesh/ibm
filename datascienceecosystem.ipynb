# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Pyhton
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Seaborn
# 4. Matplotlib

# %% [markdown]
# # Data Science Tools
#
# | Category            | Tool                          | Description                                         |
# |---------------------|-------------------------------|-----------------------------------------------------|
# | **Programming Languages** | Python                    | General-purpose programming language with extensive libraries for data science. |
# |                        | R                         | Statistical computing and graphics.                  |
# | **Data Manipulation & Analysis** | Pandas               | Data manipulation and analysis library for Python.  |
# |                                 | NumPy                | Numerical computing library for Python.             |
# |                                 | dplyr (R)            | Data manipulation package for R.                   |
# | **Data Visualization**      | Matplotlib           | 2D plotting library for Python.                     |
# |                            | Seaborn               | Statistical data visualization based on Matplotlib. |
# |                            | ggplot2 (R)           | Grammar of Graphics-based plotting system for R.   |
# | **Machine Learning**        | scikit-learn          | Simple and efficient tools for data mining and data analysis. |
# |                            | TensorFlow            | Open-source machine learning framework developed by Google. |
# |                            | PyTorch               | Open-source machine learning library developed by Facebook. |
# | **Statistical Analysis**    | Statsmodels           | Statistical models in Python.                       |
# |                            | RStudio               | IDE for R, including tools for statistical computing and graphics. |
# | **Big Data**               | Apache Spark          | Fast and general-purpose cluster computing system.  |
# |                            | Hadoop                | Framework for distributed storage and processing of large data sets. |
# | **Database & SQL**         | SQL                   | Standard language for relational database management and manipulation. |
# |                            | SQLite                | C library that provides a lightweight disk-based database. |
# | **Version Control**        | Git                   | Distributed version control system.                |
# |                            | GitHub                | Web-based platform for version control and collaboration. |
# | **Notebooks**              | Jupyter               | Open-source web application for creating and sharing documents that contain live code, equations, visualizations, and narrative text. |
# |                            | R Markdown            | Dynamic documents for R in a variety of formats.    |

# %% [markdown]
# # Arithmetic Expressions Examples
#
# Arithmetic expressions involve mathematical operations such as addition, subtraction, multiplication, and division.
# These expressions are fundamental in mathematics and play a crucial role in various scientific and programming contexts. Below are some examples of arithmetic expressions:
#
# # Addition Example
# 3 + 5 = 8
#
# # Subtraction Example
# 10 - 7 = 3
#
# # Multiplication Example
# 4 * 6 = 24
#
# # Division Example
# 15 / 3 = 5
#
# # Mixed Operations Example
# (2 + 4) * 3 = 18

# %%
# This is a simple arithmetic expression to multiply then add integers.
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
minutes = 200
hours = minutes // 60
hours
# Out:
# 3

# %% [markdown]
# # Objectives:
#
# - Understand and create arithmetic expressions in mathematics.
# - Explore popular data science tools and their applications.
# - Execute basic arithmetic operations in a Python code cell.
# - Convert units, such as minutes to hours, using Python.
# - Create informative markdown cells with tables and lists.

# %% [markdown]
# ## Author
#
# Dharinesh
